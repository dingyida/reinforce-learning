# %% [markdown]
# <a href="https://colab.research.google.com/github/dingyida/reinforce-learning/blob/main/lab12_1120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 12: Soft Actor Critic
#
# Train a Soft Actor-Critic (SAC) agent on HalfCheetah-v4,
# track its learning curve, and compare the result with your previous RL algorithm.
#
# We will learn to use the **stable_baselines3** library
#
#
# ## To start
# Run the following code that solves **the Pendulum problem**

# %%
# Install dependencies
# !pip install "stable-baselines3[extra]" "gymnasium[classic_control]"
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium[classic_control] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.12.0.88)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic_control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic_control]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 18.5 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.0

# %% [markdown]
# The following code trains a full SAC agent — with two critics, entropy tuning, and replay buffer — out of the box

# %%
import gymnasium as gym
from stable_baselines3 import SAC

# Create environment
env = gym.make("Pendulum-v1")

# Create SAC model
model = SAC("MlpPolicy", env, verbose=1)

# Train the agent with N time steps
N = 4000
model.learn(total_timesteps=N)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.43e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 93        |
# |    time_elapsed    | 8         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 25.7      |
# |    critic_loss     | 0.105     |
# |    ent_coef        | 0.813     |
# |    ent_coef_loss   | -0.336    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.52e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 92        |
# |    time_elapsed    | 17        |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 50.8      |
# |    critic_loss     | 0.0949    |
# |    ent_coef        | 0.647     |
# |    ent_coef_loss   | -0.601    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.37e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 91        |
# |    time_elapsed    | 26        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 70.4      |
# |    critic_loss     | 0.162     |
# |    ent_coef        | 0.533     |
# |    ent_coef_loss   | -0.581    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.26e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 91        |
# |    time_elapsed    | 34        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 84.8      |
# |    critic_loss     | 0.51      |
# |    ent_coef        | 0.454     |
# |    ent_coef_loss   | -0.491    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.06e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 92        |
# |    time_elapsed    | 43        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 91        |
# |    critic_loss     | 0.826     |
# |    ent_coef        | 0.393     |
# |    ent_coef_loss   | -0.478    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------

# %% [markdown]
# # Visualize the result

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import gymnasium as gym
from stable_baselines3 import SAC
from IPython.display import HTML

env = gym.make("Pendulum-v1", render_mode="rgb_array")


N_steps = 500

frames = []
obs, _ = env.reset()
for _ in range(N_steps):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    frame = env.render()
    frames.append(frame)
    if done or truncated:
        obs, _ = env.reset()

env.close()

# Create matplotlib animation
fig = plt.figure()
img = plt.imshow(frames[0])

def animate(i):
    img.set_data(frames[i])
    return [img]

ani = animation.FuncAnimation(fig, animate, frames=len(frames), interval=30)

plt.close()
HTML(ani.to_html5_video())
# Out:
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Exercise 1: Soft Actor-Critic on HalfCheetah
# **Goal:**
# Adapt the existing Soft Actor-Critic (SAC) implementation from the Pendulum-v1 environment to train and evaluate a SAC agent on the more challenging HalfCheetah-v4 task.
#
# ### Instructions
#
# 1. Adapt your code: Modify your previous SAC implementation so that it runs on the HalfCheetah-v4 environment from MuJoCo.
#
# 2. Reward Logger:
# Implement a custom RewardLogger callback to record episode rewards during training (you will have to search online about how to create a class for logger).
# After training, use the logged data to plot the learning curve (episode reward vs. timesteps).
#
# 3. Experimentation:
#     * Compare the performance of SAC on HalfCheetah-v4 with your previous algorithm.
#     * Adjust the entropy temperature parameter (ent_coef or target_entropy) and observe how this affects: Exploration behavior, Convergence speed, and Final performance.
#
# Answer the following questions
# 1. Did SAC reach a higher average reward or converge faster than your previous method?
#
# 2. How did changing the temperature for entropy affect the performance and stability of learning?
#
# 3. Describe any differences you observed in exploration or motion behavior of the agent.
#
#
# ### Deliverables
#
# * Python notebook or script containing:
#     * The adapted SAC training code
#     * The RewardLogger implementation
#     * Learning curve plots for SAC and your previous algorithm
#     * Comparison of different entropy temperature settings
#
# * The answer of the questions above

# %% [markdown]
# Yes, SAC achieved a higher average reward and showed faster convergence compared to the previous method (TD3).
#
#
# Higher entropy temperature encourages more exploration, which leads to slower improvement in the early stage and larger reward fluctuations. Lower entropy temperature makes the policy more deterministic, resulting in faster initial learning but a higher risk of getting trapped in local optima. Overall, moderate entropy values, or an automatically decaying entropy coefficient during training, provided the best balance between exploration and exploitation, producing smoother learning curves and better final rewards.
#
#
# Under higher entropy values, the agent’s actions appear more random and uncoordinated. Under lower entropy values, the agent’s behavior becomes more regular but also more rigid and repetitive. Using SAC with automatic entropy tuning can balance exploration and stability, leading to better final rewards.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# blue-SAC         yellow-TD3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install gymnasium[mujoco]
# Out:
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Collecting mujoco>=2.1.5 (from gymnasium[mujoco])
#   Downloading mujoco-3.3.7-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.37.2)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (25.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.13.0)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)
# Downloading mujoco-3.3.7-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 120.4 MB/s eta 0:00:00
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 31.0 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.10.0 mujoco-3.3.7

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardLogger(BaseCallback):

    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_timesteps = []

        self._current_ep_reward = 0.0
        self._current_ep_len = 0

    def _on_step(self) -> bool:

        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]

        self._current_ep_reward += reward
        self._current_ep_len += 1


        if done:
            self.episode_rewards.append(self._current_ep_reward)
            self.episode_lengths.append(self._current_ep_len)
            self.episode_timesteps.append(self.num_timesteps)

            if self.verbose > 0:
                print(f"Episode finished: reward={self._current_ep_reward:.2f}, length={self._current_ep_len}, timesteps={self.num_timesteps}")


            self._current_ep_reward = 0.0
            self._current_ep_len = 0

        return True

import gymnasium as gym
from stable_baselines3 import SAC
import matplotlib.pyplot as plt

env = gym.make("HalfCheetah-v4")


model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    ent_coef="auto",
)


reward_logger = RewardLogger(verbose=1)


N_TIMESTEPS = 100_000
model.learn(total_timesteps=N_TIMESTEPS, callback=reward_logger)

env.close()


timesteps = reward_logger.episode_timesteps
episode_rewards = reward_logger.episode_rewards

plt.figure()
plt.plot(timesteps, episode_rewards)
plt.xlabel("Timesteps")
plt.ylabel("Episode Reward (Return)")
plt.title("SAC on HalfCheetah-v4 (ent_coef='auto')")
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode finished: reward=-221.63, length=1000, timesteps=1000
# Episode finished: reward=-348.28, length=1000, timesteps=2000
# Episode finished: reward=-196.82, length=1000, timesteps=3000
# Episode finished: reward=-223.91, length=1000, timesteps=4000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -248     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 90       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 2.4      |
# |    ent_coef        | 0.317    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# Episode finished: reward=-117.60, length=1000, timesteps=5000
# Episode finished: reward=-206.17, length=1000, timesteps=6000
# Episode finished: reward=-40.79, length=1000, timesteps=7000
# Episode finished: reward=-179.17, length=1000, timesteps=8000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 88       |
# |    time_elapsed    | 90       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -28.8    |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -16.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# Episode finished: reward=-51.44, length=1000, timesteps=9000
# Episode finished: reward=-269.78, length=1000, timesteps=10000
# Episode finished: reward=-228.25, length=1000, timesteps=11000
# Episode finished: reward=94.70, length=1000, timesteps=12000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 88       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 1.28     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# Episode finished: reward=30.38, length=1000, timesteps=13000
# Episode finished: reward=166.41, length=1000, timesteps=14000
# Episode finished: reward=144.54, length=1000, timesteps=15000
# Episode finished: reward=121.52, length=1000, timesteps=16000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -95.4    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 88       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 1.26     |
# |    ent_coef        | 0.0139   |
# |    ent_coef_loss   | -6.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# Episode finished: reward=335.37, length=1000, timesteps=17000
# Episode finished: reward=417.94, length=1000, timesteps=18000
# Episode finished: reward=521.36, length=1000, timesteps=19000
# Episode finished: reward=584.01, length=1000, timesteps=20000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 88       |
# |    time_elapsed    | 226      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | 2.36     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# Episode finished: reward=717.88, length=1000, timesteps=21000
# Episode finished: reward=650.68, length=1000, timesteps=22000
# Episode finished: reward=970.97, length=1000, timesteps=23000
# Episode finished: reward=911.68, length=1000, timesteps=24000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 88       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 1.93     |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# Episode finished: reward=977.28, length=1000, timesteps=25000
# Episode finished: reward=783.61, length=1000, timesteps=26000
# Episode finished: reward=1415.94, length=1000, timesteps=27000
# Episode finished: reward=1490.10, length=1000, timesteps=28000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 295      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 88       |
# |    time_elapsed    | 318      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -25.8    |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.0222   |
# |    ent_coef_loss   | 4.36     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27899    |
# ---------------------------------
# Episode finished: reward=1599.21, length=1000, timesteps=29000
# Episode finished: reward=1817.62, length=1000, timesteps=30000
# Episode finished: reward=1897.05, length=1000, timesteps=31000
# Episode finished: reward=2094.68, length=1000, timesteps=32000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 489      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 88       |
# |    time_elapsed    | 363      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 3.28     |
# |    ent_coef        | 0.0346   |
# |    ent_coef_loss   | -0.0785  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31899    |
# ---------------------------------
# Episode finished: reward=2307.27, length=1000, timesteps=33000
# Episode finished: reward=2419.70, length=1000, timesteps=34000
# Episode finished: reward=2648.47, length=1000, timesteps=35000
# Episode finished: reward=2636.43, length=1000, timesteps=36000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 713      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 88       |
# |    time_elapsed    | 408      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -50.7    |
# |    critic_loss     | 4.14     |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35899    |
# ---------------------------------
# Episode finished: reward=2488.12, length=1000, timesteps=37000
# Episode finished: reward=2403.33, length=1000, timesteps=38000
# Episode finished: reward=2910.26, length=1000, timesteps=39000
# Episode finished: reward=3004.59, length=1000, timesteps=40000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 912      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 88       |
# |    time_elapsed    | 454      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -63.2    |
# |    critic_loss     | 5.51     |
# |    ent_coef        | 0.0576   |
# |    ent_coef_loss   | -0.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# Episode finished: reward=3098.03, length=1000, timesteps=41000
# Episode finished: reward=2994.34, length=1000, timesteps=42000
# Episode finished: reward=2906.91, length=1000, timesteps=43000
# Episode finished: reward=3202.54, length=1000, timesteps=44000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 88       |
# |    time_elapsed    | 499      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -79.4    |
# |    critic_loss     | 6.85     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | -0.397   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43899    |
# ---------------------------------
# Episode finished: reward=2088.63, length=1000, timesteps=45000
# Episode finished: reward=3199.35, length=1000, timesteps=46000
# Episode finished: reward=609.82, length=1000, timesteps=47000
# Episode finished: reward=3357.96, length=1000, timesteps=48000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 88       |
# |    time_elapsed    | 545      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -93.5    |
# |    critic_loss     | 6.97     |
# |    ent_coef        | 0.0729   |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47899    |
# ---------------------------------
# Episode finished: reward=3377.37, length=1000, timesteps=49000
# Episode finished: reward=3462.70, length=1000, timesteps=50000
# Episode finished: reward=3516.09, length=1000, timesteps=51000
# Episode finished: reward=3414.59, length=1000, timesteps=52000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.38e+03 |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 87       |
# |    time_elapsed    | 590      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 7.03     |
# |    ent_coef        | 0.0797   |
# |    ent_coef_loss   | 0.488    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51899    |
# ---------------------------------
# Episode finished: reward=3666.91, length=1000, timesteps=53000
# Episode finished: reward=3474.49, length=1000, timesteps=54000
# Episode finished: reward=3444.70, length=1000, timesteps=55000
# Episode finished: reward=3615.19, length=1000, timesteps=56000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.53e+03 |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 87       |
# |    time_elapsed    | 637      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 7.83     |
# |    ent_coef        | 0.0876   |
# |    ent_coef_loss   | 0.115    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55899    |
# ---------------------------------
# Episode finished: reward=3473.76, length=1000, timesteps=57000
# Episode finished: reward=3558.81, length=1000, timesteps=58000
# Episode finished: reward=3638.66, length=1000, timesteps=59000
# Episode finished: reward=3501.90, length=1000, timesteps=60000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.67e+03 |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 87       |
# |    time_elapsed    | 682      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 7.02     |
# |    ent_coef        | 0.0943   |
# |    ent_coef_loss   | -0.695   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59899    |
# ---------------------------------
# Episode finished: reward=3400.62, length=1000, timesteps=61000
# Episode finished: reward=3771.33, length=1000, timesteps=62000
# Episode finished: reward=3705.72, length=1000, timesteps=63000
# Episode finished: reward=3621.61, length=1000, timesteps=64000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.79e+03 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 87       |
# |    time_elapsed    | 728      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 7.21     |
# |    ent_coef        | 0.0994   |
# |    ent_coef_loss   | -0.708   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63899    |
# ---------------------------------
# Episode finished: reward=3672.54, length=1000, timesteps=65000
# Episode finished: reward=3658.07, length=1000, timesteps=66000
# Episode finished: reward=3498.03, length=1000, timesteps=67000
# Episode finished: reward=3742.88, length=1000, timesteps=68000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 87       |
# |    time_elapsed    | 774      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 8.95     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | 0.193    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67899    |
# ---------------------------------
# Episode finished: reward=3788.38, length=1000, timesteps=69000
# Episode finished: reward=3819.13, length=1000, timesteps=70000
# Episode finished: reward=3627.70, length=1000, timesteps=71000
# Episode finished: reward=3721.69, length=1000, timesteps=72000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2e+03    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 87       |
# |    time_elapsed    | 820      |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 8.24     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71899    |
# ---------------------------------
# Episode finished: reward=3921.35, length=1000, timesteps=73000
# Episode finished: reward=3776.77, length=1000, timesteps=74000
# Episode finished: reward=3932.13, length=1000, timesteps=75000
# Episode finished: reward=3886.24, length=1000, timesteps=76000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.1e+03  |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 87       |
# |    time_elapsed    | 866      |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -179     |
# |    critic_loss     | 7.44     |
# |    ent_coef        | 0.114    |
# |    ent_coef_loss   | 0.178    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75899    |
# ---------------------------------
# Episode finished: reward=3895.67, length=1000, timesteps=77000
# Episode finished: reward=3655.46, length=1000, timesteps=78000
# Episode finished: reward=3793.24, length=1000, timesteps=79000
# Episode finished: reward=3893.12, length=1000, timesteps=80000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.19e+03 |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 87       |
# |    time_elapsed    | 911      |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -180     |
# |    critic_loss     | 8.33     |
# |    ent_coef        | 0.114    |
# |    ent_coef_loss   | -0.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79899    |
# ---------------------------------
# Episode finished: reward=3835.39, length=1000, timesteps=81000
# Episode finished: reward=3914.15, length=1000, timesteps=82000
# Episode finished: reward=-278.03, length=1000, timesteps=83000
# Episode finished: reward=3879.49, length=1000, timesteps=84000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 87       |
# |    time_elapsed    | 956      |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -197     |
# |    critic_loss     | 8.65     |
# |    ent_coef        | 0.115    |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83899    |
# ---------------------------------
# Episode finished: reward=3985.45, length=1000, timesteps=85000
# Episode finished: reward=3998.80, length=1000, timesteps=86000
# Episode finished: reward=4054.69, length=1000, timesteps=87000
# Episode finished: reward=3792.83, length=1000, timesteps=88000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 87       |
# |    time_elapsed    | 1002     |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 7.79     |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | 1.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87899    |
# ---------------------------------
# Episode finished: reward=3915.92, length=1000, timesteps=89000
# Episode finished: reward=3850.80, length=1000, timesteps=90000
# Episode finished: reward=4077.10, length=1000, timesteps=91000
# Episode finished: reward=3938.31, length=1000, timesteps=92000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 87       |
# |    time_elapsed    | 1048     |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -202     |
# |    critic_loss     | 7.44     |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | 0.615    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91899    |
# ---------------------------------
# Episode finished: reward=4001.95, length=1000, timesteps=93000
# Episode finished: reward=4069.23, length=1000, timesteps=94000
# Episode finished: reward=3942.49, length=1000, timesteps=95000
# Episode finished: reward=4014.91, length=1000, timesteps=96000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.44e+03 |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 87       |
# |    time_elapsed    | 1093     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -211     |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.121    |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95899    |
# ---------------------------------
# Episode finished: reward=3877.17, length=1000, timesteps=97000
# Episode finished: reward=3982.29, length=1000, timesteps=98000
# Episode finished: reward=4004.60, length=1000, timesteps=99000
# Episode finished: reward=3913.27, length=1000, timesteps=100000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.5e+03  |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 87       |
# |    time_elapsed    | 1138     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -209     |
# |    critic_loss     | 9.59     |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -0.778   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99899    |
# ---------------------------------

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardLogger(BaseCallback):

    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_timesteps = []

        self._current_ep_reward = 0.0
        self._current_ep_len = 0

    def _on_step(self) -> bool:

        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]

        self._current_ep_reward += reward
        self._current_ep_len += 1


        if done:
            self.episode_rewards.append(self._current_ep_reward)
            self.episode_lengths.append(self._current_ep_len)
            self.episode_timesteps.append(self.num_timesteps)

            if self.verbose > 0:
                print(f"Episode finished: reward={self._current_ep_reward:.2f}, length={self._current_ep_len}, timesteps={self.num_timesteps}")


            self._current_ep_reward = 0.0
            self._current_ep_len = 0

        return True

import gymnasium as gym
from stable_baselines3 import SAC
import matplotlib.pyplot as plt

env = gym.make("HalfCheetah-v4")


model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    ent_coef="0.01",
)


reward_logger = RewardLogger(verbose=1)


N_TIMESTEPS = 50_000
model.learn(total_timesteps=N_TIMESTEPS, callback=reward_logger)

env.close()


timesteps = reward_logger.episode_timesteps
episode_rewards = reward_logger.episode_rewards

plt.figure()
plt.plot(timesteps, episode_rewards)
plt.xlabel("Timesteps")
plt.ylabel("Episode Reward (Return)")
plt.title("SAC on HalfCheetah-v4 (ent_coef='0.01')")
plt.grid(True)
plt.show()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode finished: reward=-227.59, length=1000, timesteps=1000
# Episode finished: reward=-244.75, length=1000, timesteps=2000
# Episode finished: reward=-178.09, length=1000, timesteps=3000
# Episode finished: reward=-264.58, length=1000, timesteps=4000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 96       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 2.8      |
# |    critic_loss     | 0.748    |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# Episode finished: reward=-361.75, length=1000, timesteps=5000
# Episode finished: reward=-364.89, length=1000, timesteps=6000
# Episode finished: reward=-276.67, length=1000, timesteps=7000
# Episode finished: reward=-279.15, length=1000, timesteps=8000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -275     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 95       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 7.72     |
# |    critic_loss     | 0.526    |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# Episode finished: reward=-238.61, length=1000, timesteps=9000
# Episode finished: reward=6.04, length=1000, timesteps=10000
# Episode finished: reward=-229.93, length=1000, timesteps=11000
# Episode finished: reward=-141.14, length=1000, timesteps=12000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 94       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 10.5     |
# |    critic_loss     | 0.711    |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# Episode finished: reward=62.59, length=1000, timesteps=13000
# Episode finished: reward=167.54, length=1000, timesteps=14000
# Episode finished: reward=223.08, length=1000, timesteps=15000
# Episode finished: reward=274.39, length=1000, timesteps=16000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 94       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | 9.77     |
# |    critic_loss     | 0.899    |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# Episode finished: reward=268.17, length=1000, timesteps=17000
# Episode finished: reward=425.28, length=1000, timesteps=18000
# Episode finished: reward=879.05, length=1000, timesteps=19000
# Episode finished: reward=1093.37, length=1000, timesteps=20000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 29.6     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 94       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | 4.86     |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# Episode finished: reward=960.99, length=1000, timesteps=21000
# Episode finished: reward=1383.42, length=1000, timesteps=22000
# Episode finished: reward=1104.18, length=1000, timesteps=23000
# Episode finished: reward=1430.63, length=1000, timesteps=24000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 228      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 94       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -4.07    |
# |    critic_loss     | 1.63     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# Episode finished: reward=1416.69, length=1000, timesteps=25000
# Episode finished: reward=1405.64, length=1000, timesteps=26000
# Episode finished: reward=1317.06, length=1000, timesteps=27000
# Episode finished: reward=1277.79, length=1000, timesteps=28000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 389      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 1.89     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27899    |
# ---------------------------------
# Episode finished: reward=1568.62, length=1000, timesteps=29000
# Episode finished: reward=1650.85, length=1000, timesteps=30000
# Episode finished: reward=1598.03, length=1000, timesteps=31000
# Episode finished: reward=1745.09, length=1000, timesteps=32000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 545      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 94       |
# |    time_elapsed    | 339      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -29.5    |
# |    critic_loss     | 2.95     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31899    |
# ---------------------------------
# Episode finished: reward=1684.17, length=1000, timesteps=33000
# Episode finished: reward=2069.64, length=1000, timesteps=34000
# Episode finished: reward=2231.51, length=1000, timesteps=35000
# Episode finished: reward=2254.80, length=1000, timesteps=36000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 714      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 94       |
# |    time_elapsed    | 382      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -41.4    |
# |    critic_loss     | 3.63     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35899    |
# ---------------------------------
# Episode finished: reward=1109.52, length=1000, timesteps=37000
# Episode finished: reward=848.41, length=1000, timesteps=38000
# Episode finished: reward=2270.00, length=1000, timesteps=39000
# Episode finished: reward=2549.47, length=1000, timesteps=40000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 812      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 94       |
# |    time_elapsed    | 424      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -49      |
# |    critic_loss     | 3.96     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# Episode finished: reward=2386.70, length=1000, timesteps=41000
# Episode finished: reward=2703.75, length=1000, timesteps=42000
# Episode finished: reward=2620.98, length=1000, timesteps=43000
# Episode finished: reward=2653.67, length=1000, timesteps=44000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 973      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 94       |
# |    time_elapsed    | 466      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -65.8    |
# |    critic_loss     | 4.81     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43899    |
# ---------------------------------
# Episode finished: reward=2678.31, length=1000, timesteps=45000
# Episode finished: reward=3093.90, length=1000, timesteps=46000
# Episode finished: reward=3070.35, length=1000, timesteps=47000
# Episode finished: reward=3026.28, length=1000, timesteps=48000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 94       |
# |    time_elapsed    | 508      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -85.4    |
# |    critic_loss     | 8.04     |
# |    ent_coef        | 0.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47899    |
# ---------------------------------
# Episode finished: reward=3071.89, length=1000, timesteps=49000
# Episode finished: reward=3194.65, length=1000, timesteps=50000

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardLogger(BaseCallback):

    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_timesteps = []

        self._current_ep_reward = 0.0
        self._current_ep_len = 0

    def _on_step(self) -> bool:

        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]

        self._current_ep_reward += reward
        self._current_ep_len += 1


        if done:
            self.episode_rewards.append(self._current_ep_reward)
            self.episode_lengths.append(self._current_ep_len)
            self.episode_timesteps.append(self.num_timesteps)

            if self.verbose > 0:
                print(f"Episode finished: reward={self._current_ep_reward:.2f}, length={self._current_ep_len}, timesteps={self.num_timesteps}")


            self._current_ep_reward = 0.0
            self._current_ep_len = 0

        return True

import gymnasium as gym
from stable_baselines3 import SAC
import matplotlib.pyplot as plt

env = gym.make("HalfCheetah-v4")


model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    ent_coef="0.1",
)


reward_logger = RewardLogger(verbose=1)


N_TIMESTEPS = 50_000
model.learn(total_timesteps=N_TIMESTEPS, callback=reward_logger)

env.close()


timesteps = reward_logger.episode_timesteps
episode_rewards = reward_logger.episode_rewards

plt.figure()
plt.plot(timesteps, episode_rewards)
plt.xlabel("Timesteps")
plt.ylabel("Episode Reward (Return)")
plt.title("SAC on HalfCheetah-v4 (ent_coef='0.1')")
plt.grid(True)
plt.show()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode finished: reward=-249.57, length=1000, timesteps=1000
# Episode finished: reward=-67.94, length=1000, timesteps=2000
# Episode finished: reward=-255.01, length=1000, timesteps=3000
# Episode finished: reward=-159.85, length=1000, timesteps=4000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -183     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 97       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -1.13    |
# |    critic_loss     | 0.72     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# Episode finished: reward=-188.81, length=1000, timesteps=5000
# Episode finished: reward=-99.11, length=1000, timesteps=6000
# Episode finished: reward=-228.80, length=1000, timesteps=7000
# Episode finished: reward=3.45, length=1000, timesteps=8000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -156     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 95       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -0.0869  |
# |    critic_loss     | 0.44     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# Episode finished: reward=-39.15, length=1000, timesteps=9000
# Episode finished: reward=-83.48, length=1000, timesteps=10000
# Episode finished: reward=46.23, length=1000, timesteps=11000
# Episode finished: reward=122.15, length=1000, timesteps=12000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 95       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -1.67    |
# |    critic_loss     | 0.502    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# Episode finished: reward=89.19, length=1000, timesteps=13000
# Episode finished: reward=137.25, length=1000, timesteps=14000
# Episode finished: reward=-32.58, length=1000, timesteps=15000
# Episode finished: reward=198.09, length=1000, timesteps=16000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -50.5    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 95       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -2.65    |
# |    critic_loss     | 0.582    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# Episode finished: reward=292.27, length=1000, timesteps=17000
# Episode finished: reward=309.10, length=1000, timesteps=18000
# Episode finished: reward=416.24, length=1000, timesteps=19000
# Episode finished: reward=161.18, length=1000, timesteps=20000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 18.5     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 94       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -6.45    |
# |    critic_loss     | 0.628    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# Episode finished: reward=-197.78, length=1000, timesteps=21000
# Episode finished: reward=-56.95, length=1000, timesteps=22000
# Episode finished: reward=628.89, length=1000, timesteps=23000
# Episode finished: reward=-143.55, length=1000, timesteps=24000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 25.1     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 94       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -7.76    |
# |    critic_loss     | 0.776    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# Episode finished: reward=606.92, length=1000, timesteps=25000
# Episode finished: reward=729.88, length=1000, timesteps=26000
# Episode finished: reward=741.53, length=1000, timesteps=27000
# Episode finished: reward=980.88, length=1000, timesteps=28000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 295      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.957    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27899    |
# ---------------------------------
# Episode finished: reward=1143.91, length=1000, timesteps=29000
# Episode finished: reward=1293.59, length=1000, timesteps=30000
# Episode finished: reward=197.22, length=1000, timesteps=31000
# Episode finished: reward=1582.03, length=1000, timesteps=32000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 94       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31899    |
# ---------------------------------
# Episode finished: reward=1514.07, length=1000, timesteps=33000
# Episode finished: reward=1631.74, length=1000, timesteps=34000
# Episode finished: reward=1712.25, length=1000, timesteps=35000
# Episode finished: reward=1779.76, length=1000, timesteps=36000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 403      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 94       |
# |    time_elapsed    | 380      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -26      |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35899    |
# ---------------------------------
# Episode finished: reward=1243.71, length=1000, timesteps=37000
# Episode finished: reward=428.31, length=1000, timesteps=38000
# Episode finished: reward=1333.58, length=1000, timesteps=39000
# Episode finished: reward=2187.72, length=1000, timesteps=40000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 493      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 94       |
# |    time_elapsed    | 422      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -36.6    |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# Episode finished: reward=2093.49, length=1000, timesteps=41000
# Episode finished: reward=2352.74, length=1000, timesteps=42000
# Episode finished: reward=2249.58, length=1000, timesteps=43000
# Episode finished: reward=1756.15, length=1000, timesteps=44000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 640      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 94       |
# |    time_elapsed    | 465      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -50.2    |
# |    critic_loss     | 3.03     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43899    |
# ---------------------------------
# Episode finished: reward=1881.60, length=1000, timesteps=45000
# Episode finished: reward=2404.63, length=1000, timesteps=46000
# Episode finished: reward=2309.49, length=1000, timesteps=47000
# Episode finished: reward=2367.10, length=1000, timesteps=48000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 773      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 94       |
# |    time_elapsed    | 508      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -58.8    |
# |    critic_loss     | 4.05     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47899    |
# ---------------------------------
# Episode finished: reward=2477.91, length=1000, timesteps=49000
# Episode finished: reward=2518.91, length=1000, timesteps=50000

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardLogger(BaseCallback):

    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_timesteps = []

        self._current_ep_reward = 0.0
        self._current_ep_len = 0

    def _on_step(self) -> bool:

        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]

        self._current_ep_reward += reward
        self._current_ep_len += 1


        if done:
            self.episode_rewards.append(self._current_ep_reward)
            self.episode_lengths.append(self._current_ep_len)
            self.episode_timesteps.append(self.num_timesteps)

            if self.verbose > 0:
                print(f"Episode finished: reward={self._current_ep_reward:.2f}, length={self._current_ep_len}, timesteps={self.num_timesteps}")


            self._current_ep_reward = 0.0
            self._current_ep_len = 0

        return True

import gymnasium as gym
from stable_baselines3 import SAC
import matplotlib.pyplot as plt

env = gym.make("HalfCheetah-v4")


model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    ent_coef="0.001",
)


reward_logger = RewardLogger(verbose=1)


N_TIMESTEPS = 50_000
model.learn(total_timesteps=N_TIMESTEPS, callback=reward_logger)

env.close()


timesteps = reward_logger.episode_timesteps
episode_rewards = reward_logger.episode_rewards

plt.figure()
plt.plot(timesteps, episode_rewards)
plt.xlabel("Timesteps")
plt.ylabel("Episode Reward (Return)")
plt.title("SAC on HalfCheetah-v4 (ent_coef='0.001')")
plt.grid(True)
plt.show()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode finished: reward=-327.78, length=1000, timesteps=1000
# Episode finished: reward=-255.20, length=1000, timesteps=2000
# Episode finished: reward=-144.99, length=1000, timesteps=3000
# Episode finished: reward=-240.66, length=1000, timesteps=4000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -242     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 96       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 2.31     |
# |    critic_loss     | 0.712    |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# Episode finished: reward=-139.95, length=1000, timesteps=5000
# Episode finished: reward=-25.72, length=1000, timesteps=6000
# Episode finished: reward=110.03, length=1000, timesteps=7000
# Episode finished: reward=100.57, length=1000, timesteps=8000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 95       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 1.37     |
# |    critic_loss     | 0.47     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# Episode finished: reward=150.00, length=1000, timesteps=9000
# Episode finished: reward=183.94, length=1000, timesteps=10000
# Episode finished: reward=148.07, length=1000, timesteps=11000
# Episode finished: reward=123.75, length=1000, timesteps=12000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -26.5    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 94       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -1.09    |
# |    critic_loss     | 0.422    |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# Episode finished: reward=145.00, length=1000, timesteps=13000
# Episode finished: reward=200.96, length=1000, timesteps=14000
# Episode finished: reward=210.92, length=1000, timesteps=15000
# Episode finished: reward=204.65, length=1000, timesteps=16000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 27.7     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 94       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -2.72    |
# |    critic_loss     | 0.441    |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# Episode finished: reward=263.94, length=1000, timesteps=17000
# Episode finished: reward=392.24, length=1000, timesteps=18000
# Episode finished: reward=227.05, length=1000, timesteps=19000
# Episode finished: reward=549.65, length=1000, timesteps=20000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 93.8     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 94       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -4.94    |
# |    critic_loss     | 0.512    |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# Episode finished: reward=612.12, length=1000, timesteps=21000
# Episode finished: reward=691.81, length=1000, timesteps=22000
# Episode finished: reward=814.11, length=1000, timesteps=23000
# Episode finished: reward=1041.98, length=1000, timesteps=24000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 94       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -9.15    |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# Episode finished: reward=1009.10, length=1000, timesteps=25000
# Episode finished: reward=1204.62, length=1000, timesteps=26000
# Episode finished: reward=1214.70, length=1000, timesteps=27000
# Episode finished: reward=1250.20, length=1000, timesteps=28000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 347      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27899    |
# ---------------------------------
# Episode finished: reward=1238.44, length=1000, timesteps=29000
# Episode finished: reward=1509.71, length=1000, timesteps=30000
# Episode finished: reward=166.11, length=1000, timesteps=31000
# Episode finished: reward=1681.62, length=1000, timesteps=32000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 447      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 94       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 1.95     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31899    |
# ---------------------------------
# Episode finished: reward=1514.74, length=1000, timesteps=33000
# Episode finished: reward=1549.76, length=1000, timesteps=34000
# Episode finished: reward=1632.18, length=1000, timesteps=35000
# Episode finished: reward=1727.24, length=1000, timesteps=36000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 576      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 94       |
# |    time_elapsed    | 381      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35899    |
# ---------------------------------
# Episode finished: reward=1639.70, length=1000, timesteps=37000
# Episode finished: reward=1573.48, length=1000, timesteps=38000
# Episode finished: reward=1634.61, length=1000, timesteps=39000
# Episode finished: reward=1662.79, length=1000, timesteps=40000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 681      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 94       |
# |    time_elapsed    | 423      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -51.4    |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# Episode finished: reward=1651.54, length=1000, timesteps=41000
# Episode finished: reward=1698.45, length=1000, timesteps=42000
# Episode finished: reward=1763.91, length=1000, timesteps=43000
# Episode finished: reward=1761.45, length=1000, timesteps=44000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 775      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 94       |
# |    time_elapsed    | 466      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -65.7    |
# |    critic_loss     | 2.62     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43899    |
# ---------------------------------
# Episode finished: reward=1747.06, length=1000, timesteps=45000
# Episode finished: reward=1843.29, length=1000, timesteps=46000
# Episode finished: reward=1997.08, length=1000, timesteps=47000
# Episode finished: reward=1987.93, length=1000, timesteps=48000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 869      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 94       |
# |    time_elapsed    | 508      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -79.5    |
# |    critic_loss     | 3.06     |
# |    ent_coef        | 0.001    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47899    |
# ---------------------------------
# Episode finished: reward=1914.43, length=1000, timesteps=49000
# Episode finished: reward=2117.34, length=1000, timesteps=50000

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import gymnasium as gym
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise
import matplotlib.pyplot as plt


class RewardLogger(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_timesteps = []
        self._current_ep_reward = 0.0
        self._current_ep_len = 0

    def _on_step(self) -> bool:
        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]

        self._current_ep_reward += reward
        self._current_ep_len += 1

        if done:
            self.episode_rewards.append(self._current_ep_reward)
            self.episode_lengths.append(self._current_ep_len)
            self.episode_timesteps.append(self.num_timesteps)

            if self.verbose > 0:
                print(
                    f"Episode finished: reward={self._current_ep_reward:.2f}, "
                    f"length={self._current_ep_len}, timesteps={self.num_timesteps}"
                )

            self._current_ep_reward = 0.0
            self._current_ep_len = 0

        return True


env = gym.make("HalfCheetah-v4")


n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(
    mean=np.zeros(n_actions),
    sigma=0.1 * np.ones(n_actions)   #
)


model = TD3(
    "MlpPolicy",
    env,
    action_noise=action_noise,
    verbose=1,

)


reward_logger = RewardLogger(verbose=1)
N_TIMESTEPS = 50_000

model.learn(total_timesteps=N_TIMESTEPS, callback=reward_logger)
env.close()

timesteps = reward_logger.episode_timesteps
episode_rewards = reward_logger.episode_rewards

plt.figure()
plt.plot(timesteps, episode_rewards)
plt.xlabel("Timesteps")
plt.ylabel("Episode Reward (Return)")
plt.title("TD3 on HalfCheetah-v4")
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode finished: reward=-447.38, length=1000, timesteps=1000
# Episode finished: reward=-503.52, length=1000, timesteps=2000
# Episode finished: reward=-453.84, length=1000, timesteps=3000
# Episode finished: reward=-412.19, length=1000, timesteps=4000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -454     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 165      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 1.17     |
# |    critic_loss     | 0.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# Episode finished: reward=-340.83, length=1000, timesteps=5000
# Episode finished: reward=-310.93, length=1000, timesteps=6000
# Episode finished: reward=-76.12, length=1000, timesteps=7000
# Episode finished: reward=108.04, length=1000, timesteps=8000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -305     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 163      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7899     |
# ---------------------------------
# Episode finished: reward=204.71, length=1000, timesteps=9000
# Episode finished: reward=500.87, length=1000, timesteps=10000
# Episode finished: reward=526.28, length=1000, timesteps=11000
# Episode finished: reward=555.81, length=1000, timesteps=12000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -54.1    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 162      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -1.62    |
# |    critic_loss     | 0.384    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# Episode finished: reward=581.52, length=1000, timesteps=13000
# Episode finished: reward=640.97, length=1000, timesteps=14000
# Episode finished: reward=537.10, length=1000, timesteps=15000
# Episode finished: reward=266.15, length=1000, timesteps=16000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 86       |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 162      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -6.47    |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15899    |
# ---------------------------------
# Episode finished: reward=695.32, length=1000, timesteps=17000
# Episode finished: reward=775.73, length=1000, timesteps=18000
# Episode finished: reward=834.95, length=1000, timesteps=19000
# Episode finished: reward=747.70, length=1000, timesteps=20000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 162      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 1.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19899    |
# ---------------------------------
# Episode finished: reward=790.23, length=1000, timesteps=21000
# Episode finished: reward=817.12, length=1000, timesteps=22000
# Episode finished: reward=842.33, length=1000, timesteps=23000
# Episode finished: reward=794.60, length=1000, timesteps=24000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 320      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 162      |
# |    time_elapsed    | 147      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 1.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# Episode finished: reward=933.28, length=1000, timesteps=25000
# Episode finished: reward=877.54, length=1000, timesteps=26000
# Episode finished: reward=838.39, length=1000, timesteps=27000
# Episode finished: reward=863.93, length=1000, timesteps=28000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 400      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 162      |
# |    time_elapsed    | 172      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 1.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27899    |
# ---------------------------------
# Episode finished: reward=972.98, length=1000, timesteps=29000
# Episode finished: reward=481.37, length=1000, timesteps=30000
# Episode finished: reward=818.54, length=1000, timesteps=31000
# Episode finished: reward=1011.80, length=1000, timesteps=32000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 452      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 162      |
# |    time_elapsed    | 197      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 1.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31899    |
# ---------------------------------
# Episode finished: reward=912.20, length=1000, timesteps=33000
# Episode finished: reward=766.58, length=1000, timesteps=34000
# Episode finished: reward=989.82, length=1000, timesteps=35000
# Episode finished: reward=958.37, length=1000, timesteps=36000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 503      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 161      |
# |    time_elapsed    | 222      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -27.1    |
# |    critic_loss     | 2.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# Episode finished: reward=803.63, length=1000, timesteps=37000
# Episode finished: reward=912.56, length=1000, timesteps=38000
# Episode finished: reward=938.99, length=1000, timesteps=39000
# Episode finished: reward=912.67, length=1000, timesteps=40000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 542      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 162      |
# |    time_elapsed    | 246      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 1.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39899    |
# ---------------------------------
# Episode finished: reward=965.75, length=1000, timesteps=41000
# Episode finished: reward=1013.18, length=1000, timesteps=42000
# Episode finished: reward=980.61, length=1000, timesteps=43000
# Episode finished: reward=1004.93, length=1000, timesteps=44000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 583      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 161      |
# |    time_elapsed    | 271      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 2.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43899    |
# ---------------------------------
# Episode finished: reward=981.02, length=1000, timesteps=45000
# Episode finished: reward=988.51, length=1000, timesteps=46000
# Episode finished: reward=1031.33, length=1000, timesteps=47000
# Episode finished: reward=990.77, length=1000, timesteps=48000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 617      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 161      |
# |    time_elapsed    | 296      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -37      |
# |    critic_loss     | 2.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# Episode finished: reward=950.29, length=1000, timesteps=49000
# Episode finished: reward=1030.71, length=1000, timesteps=50000
